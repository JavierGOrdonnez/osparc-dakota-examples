# %% [markdown]
# This notebook aims at evaluating UQ dimensional ranges on a SuMo built through Dakota.
#
# Also, the geometrical values will not be evaluated -- see if then the mean UQ value corresponds to the default value.

# %%
import pathlib as pl
import shutil
import dakota.environment as dakenv
import sys, os
import numpy as np

# script_dir = pl.Path(__file__).parent
script_dir = pl.Path(os.getcwd())  ## how resilient is this?
print(script_dir)
sys.path.append(script_dir)

from utils import funs_create_dakota_conf, funs_data_processing
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq

# %% [markdown]
# ## Load & process input data

# %%
TRAINING_SAMPLES_FILE = "train_Norm20D_1000LHS.dat"
tmp_folder = script_dir / ".tmp_output"
if tmp_folder.exists():
    shutil.rmtree(tmp_folder)
tmp_folder.mkdir()
TRAINING_SAMPLES_FILE = shutil.copy(TRAINING_SAMPLES_FILE, tmp_folder)
PROCESSED_TRAINING_FILE = funs_data_processing.process_input_file(
    TRAINING_SAMPLES_FILE,  # N=100, filter_highest_N=10
)
variables_train = funs_data_processing.get_variable_names(PROCESSED_TRAINING_FILE)
print(variables_train)
# Out:
# ['%eval_id', 'RELDEPTH', 'DIAMETER', 'ANGLE', 'ELECTRELDEPTH', 'THICKNESS_SKIN', 'THICKNESS_SCT', 'THICKNESS_APONEUROSIS', 'THICKNESS_LOOSE_AREOLAR_TISSUE', 'THICKNESS_SKULL_OUTER', 'THICKNESS_SKULL_DIPLOE', 'THICKNESS_SKULL_INNER', 'THICKNESS_CSF', 'CONDUCTIVITY_SKIN', 'CONDUCTIVITY_SCT', 'CONDUCTIVITY_APONEUROSIS', 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE', 'CONDUCTIVITY_SKULL_CORTICAL', 'CONDUCTIVITY_SKULL_DIPLOE', 'CONDUCTIVITY_CSF', 'AFmax_4um', 'GAFmax_4um']

# %% [markdown]
# ## Sample from input distributions

# %%
import pandas as pd
import copy
from create_20D_variables import (
    GEOMETRIC_VARIABLES,
    THICKNESS_VARIABLES,
    CONDUCTIVITY_VARIABLES,
)

# %%
N_RESPONSES = 2
if "POSITION" in GEOMETRIC_VARIABLES:
    GEOMETRIC_VARIABLES.pop("POSITION")

dakota_conf_path = tmp_folder / "dakota.in"
dakota_conf = funs_create_dakota_conf.start_dakota_file()
dakota_conf += funs_create_dakota_conf.add_surrogate_model(
    PROCESSED_TRAINING_FILE, cross_validation_folds=None
)
dakota_conf += funs_create_dakota_conf.add_sampling_method(num_samples=10000, seed=None)
# dakota_conf += funs_create_dakota_conf.add_variables(
#     variables=variables_train[1:-N_RESPONSES],
# )
dakota_conf += f"""
    variables
        id_variables = "VARIABLES"
        active uncertain
        uniform_uncertain = {len(GEOMETRIC_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in GEOMETRIC_VARIABLES.keys()])}
            upper_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["initial_point"]*1.0001) for var in GEOMETRIC_VARIABLES])}
            lower_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["initial_point"]) for var in GEOMETRIC_VARIABLES])}
        normal_uncertain = {len(THICKNESS_VARIABLES)+len(CONDUCTIVITY_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in THICKNESS_VARIABLES.keys()])} {" ".join([f"'{var}'" for var in CONDUCTIVITY_VARIABLES.keys()])}
            means {" ".join([str(THICKNESS_VARIABLES[var]["mean"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["mean"]) for var in CONDUCTIVITY_VARIABLES])}
            std_deviations {" ".join([str(THICKNESS_VARIABLES[var]["std"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["std"]) for var in CONDUCTIVITY_VARIABLES])}
            lower_bounds {" ".join([str(THICKNESS_VARIABLES[var]["mean"]/5) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["mean"]/5) for var in CONDUCTIVITY_VARIABLES])}
"""
dakota_conf += funs_create_dakota_conf.add_responses(variables_train[-N_RESPONSES:])
print(dakota_conf)
funs_create_dakota_conf.write_to_file(dakota_conf, dakota_conf_path)
# Out:
#     environment
#         tabular_data
#             tabular_data_file = 'results.dat'
#
#
#         model
#             id_model 'SURR_MODEL'
#             surrogate global
#                 gaussian_process surfpack
#                 ## hopefully faster by removing CV
#                 import_build_points_file
#                     '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20D_1000LHS_processed.txt'
#                     custom_annotated header use_variable_labels eval_id
#                 export_approx_points_file "predictions.dat"
#                 export_approx_variance_file "variances.dat"
#
#         method
#             id_method = 'SAMPLING'
#             sample_type
#                 lhs
#             sampling
#                 samples = 10000
#
#
#
#     variables
#         id_variables = "VARIABLES"
#         active uncertain
#         uniform_uncertain = 4
#             descriptors 'RELDEPTH' 'DIAMETER' 'ANGLE' 'ELECTRELDEPTH'
#             upper_bounds 0.50005 0.30002999999999996 90.009 0.50005
#             lower_bounds 0.5 0.3 90.0 0.5
#         normal_uncertain = 15
#             descriptors 'THICKNESS_SKIN' 'THICKNESS_SCT' 'THICKNESS_APONEUROSIS' 'THICKNESS_LOOSE_AREOLAR_TISSUE' 'THICKNESS_SKULL_OUTER' 'THICKNESS_SKULL_DIPLOE' 'THICKNESS_SKULL_INNER' 'THICKNESS_CSF' 'CONDUCTIVITY_SKIN' 'CONDUCTIVITY_SCT' 'CONDUCTIVITY_APONEUROSIS' 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE' 'CONDUCTIVITY_SKULL_CORTICAL' 'CONDUCTIVITY_SKULL_DIPLOE' 'CONDUCTIVITY_CSF'
#             means 0.514 0.944 0.247 0.655 1.83 2.84 1.44 3.6 0.148297101 0.077621273 0.079195857 0.079195857 0.00644673 0.09975 1.87899971
#             std_deviations 0.108 0.331 0.101 0.376 0.5 0.5 0.5 0.5 0.042145684 0.093082005 0.023344569 0.023344569 0.002535023 0.121595589 0.685074315
#             lower_bounds 0.1028 0.1888 0.0494 0.131 0.366 0.568 0.288 0.72 0.029659420199999998 0.0155242546 0.015839171399999998 0.015839171399999998 0.001289346 0.019950000000000002 0.375799942
#
#
#         responses
#             id_responses = 'RESPONSES'
#             descriptors 'AFmax_4um' 'GAFmax_4um'
#             objective_functions = 2
#             no_gradients
#             no_hessians

# %% [markdown]
# ## Create & run Dakota study

# %%
os.chdir(tmp_folder)
shutil.copy(script_dir / "execute_dakota.py", tmp_folder)
# !python execute_dakota.py
os.chdir(script_dir)
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output
# Dakota version 6.19+ (stable) released Aug  8 2024.
# Repository revision 494027b (2024-04-29) built Aug  8 2024 14:37:02.
# Running serial Dakota executable in serial mode.
# Start time: Thu Sep 19 17:12:40 2024
#
# Using provided Dakota input string
# Writing new restart file 'dakota.rst'.
# Surrogate model retrieving points with 19 variables and 2 response
# functions from file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20D_1000LHS_processed.txt'
#
# Info (Surrogate model with id 'SURR_MODEL' import_build_points):
# Reordering variables imported from tabular file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20D_1000LHS_processed.txt'
# based on labels in header.
#
# Surrogate model retrieved 1000 total points.
#
# >>>>> Executing environment.
#
# >>>>> Running random_sampling iterator.
#
# NonD lhs Samples = 10000 Seed (system-generated) = 699794
#
# >>>>> Building global_kriging approximations.
# Constructing global approximations with no anchor, 0 DACE samples, and 1000 reused points.
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=19; #pts=1000; used 1000/1000 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[2.29479, 1.80555, 0.492165, 1.62417, 9.36263, 11.7736, 8.86357, 13.6713, 0.248479, 0.110103, 0.437182, 0.436852, 0.0407342, 1.44589, 12.2667, 0.98277, 0.883834, 88.444, 0.981797]^T
# found by the "global" optimization_method;
# unadjusted variance=211730; "per equation" log(likelihood)=3.15076;
# rcond(R)=1.23235e-06; rcond(G_Rinv_Gtran)=0.00412833; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 39 terms) was requested for the trend function; the build
# data was sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.559725 -0.05311*x0 -0.281188*x1 ...
#                -0.117392*x2 -0.215321*x3 + 0.00869891*x4 ...
#                -0.0115991*x5 -0.0213473*x6 -0.0016138*x7 ...
#                -0.0922316*x8 -0.319298*x9 -0.0316418*x10 ...
#                -0.070193*x11 -0.0126805*x12 + 0.010911*x13 ...
#                -0.0052879*x14 + 0.174001*x15 -0.277497*x16 ...
#                -0.0419611*x17 -0.193642*x18 + 0.0286698*x0^2 + ...
#                0.22395*x1^2 + 0.0368275*x2^2 + 0.199468*x3^2 + ...
#                0.00635028*x4^2 + 0.0137313*x5^2 + 0.0121972*x6^2 + ...
#                0.0114844*x7^2 + 0.0809821*x8^2 + 0.338463*x9^2 ...
#                -0.00113623*x10^2 + 0.0595526*x11^2 + 0.00606739*x12^2 + ...
#                0.00137059*x13^2 + 0.00704479*x14^2 + 0.0845119*x15^2 + ...
#                0.200405*x16^2 + 0.0538627*x17^2 + 0.178057*x18^2
# ------------------------------------
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=19; #pts=1000; used 1000/1000 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[2.29479, 1.80555, 1.56253, 1.62417, 9.36263, 3.70845, 8.86357, 13.6713, 0.248479, 0.110103, 0.437182, 0.1376, 0.0128305, 1.44589, 12.2667, 0.98277, 0.883834, 27.8581, 0.981797]^T
# found by the "global" optimization_method;
# unadjusted variance=57.9602; "per equation" log(likelihood)=2.9831;
# rcond(R)=5.28713e-06; rcond(G_Rinv_Gtran)=0.00311474; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 39 terms) was requested for the trend function; the build
# data was sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.435897 -0.0508249*x0 -0.218673*x1 ...
#                -0.0519788*x2 -0.0964122*x3 + 0.0484484*x4 ...
#                -0.0268778*x5 -0.00454837*x6 -0.000726167*x7 ...
#                -0.126974*x8 -0.292073*x9 -0.0468557*x10 ...
#                -0.156196*x11 -0.116504*x12 -0.0289649*x13 + ...
#                0.000747653*x14 + 0.082404*x15 -0.139164*x16 ...
#                -0.0470352*x17 -0.0835929*x18 + 0.0529319*x0^2 + ...
#                0.145897*x1^2 + 0.012895*x2^2 + 0.0861789*x3^2 ...
#                -0.0411278*x4^2 + 0.0646475*x5^2 + 0.00411011*x6^2 + ...
#                0.0015858*x7^2 + 0.0796558*x8^2 + 0.231789*x9^2 + ...
#                0.0198123*x10^2 + 0.157913*x11^2 + 0.105556*x12^2 + ...
#                0.0507521*x13^2 + 0.0221288*x14^2 + 0.0561674*x15^2 + ...
#                0.117601*x16^2 -0.134817*x17^2 + 0.0974032*x18^2
# ------------------------------------
#
# <<<<< global_kriging approximation builds completed.
# Beginning Approximate Fn Evaluations...
# <<<<< Function evaluation summary (APPROX_INTERFACE_1): 10000 total (10000 new, 0 duplicate)
# <<<<< Best parameters          =
#                       7.5326746173e-01 THICKNESS_SKIN
#                       1.3388084399e+00 THICKNESS_SCT
#                       1.6152302845e-01 THICKNESS_APONEUROSIS
#                       2.0000797728e+00 THICKNESS_LOOSE_AREOLAR_TISSUE
#                       2.2489602482e+00 THICKNESS_SKULL_OUTER
#                       3.1285214081e+00 THICKNESS_SKULL_DIPLOE
#                       1.2337027228e+00 THICKNESS_SKULL_INNER
#                       3.3100074899e+00 THICKNESS_CSF
#                       1.4005140129e-01 CONDUCTIVITY_SKIN
#                       1.3023980210e-01 CONDUCTIVITY_SCT
#                       8.7162329244e-02 CONDUCTIVITY_APONEUROSIS
#                       8.9232236345e-02 CONDUCTIVITY_LOOSE_AREOLAR_TISSUE
#                       5.8234582198e-03 CONDUCTIVITY_SKULL_CORTICAL
#                       1.0229098271e-01 CONDUCTIVITY_SKULL_DIPLOE
#                       2.9159861341e+00 CONDUCTIVITY_CSF
#                       5.0001359643e-01 RELDEPTH
#                       3.0002094353e-01 DIAMETER
#                       9.0008203888e+01 ANGLE
#                       5.0000992666e-01 ELECTRELDEPTH
# <<<<< Best objective functions =
#                       1.5836670252e+02
#                       9.3712137506e+00
# <<<<< Best evaluation ID: 3138
# -----------------------------------------------------------------------------
# Statistics based on 10000 samples:
#
# Sample moment statistics for each response function:
#                             Mean           Std Dev          Skewness          Kurtosis
#      AFmax_4um  7.4173023627e+02  2.6661686685e+02  6.9804762842e-01  4.0468680639e-01
#     GAFmax_4um  2.0078378566e+01  5.8888494982e+00  1.7369234047e-01 -2.8948854124e-01
#
# 95% confidence intervals for each response function:
#                     LowerCI_Mean      UpperCI_Mean    LowerCI_StdDev    UpperCI_StdDev
#      AFmax_4um  7.3650400908e+02  7.4695646346e+02  2.6297254422e+02  2.7036433988e+02
#     GAFmax_4um  1.9962945264e+01  2.0193811869e+01  5.8083562130e+00  5.9716210985e+00
#
# Simple Correlation Matrix among all inputs and outputs:
#              THICKNESS_SKIN THICKNESS_SCT THICKNESS_APONEUROSIS THICKNESS_LOOSE_AREOLAR_TISSUE THICKNESS_SKULL_OUTER THICKNESS_SKULL_DIPLOE THICKNESS_SKULL_INNER THICKNESS_CSF CONDUCTIVITY_SKIN CONDUCTIVITY_SCT CONDUCTIVITY_APONEUROSIS CONDUCTIVITY_LOOSE_AREOLAR_TISSUE CONDUCTIVITY_SKULL_CORTICAL CONDUCTIVITY_SKULL_DIPLOE CONDUCTIVITY_CSF     RELDEPTH     DIAMETER        ANGLE ELECTRELDEPTH    AFmax_4um   GAFmax_4um
# THICKNESS_SKIN  1.00000e+00
# THICKNESS_SCT -9.15827e-05  1.00000e+00
# THICKNESS_APONEUROSIS  2.01652e-04 -2.44086e-03  1.00000e+00
# THICKNESS_LOOSE_AREOLAR_TISSU
#   GAFmax_4um -1.06129e-01 -4.79539e-01 -2.03387e-01 -2.57447e-01 -1.74423e-02  8.11232e-03  2.23557e-03  8.22334e-03 -2.56928e-01 -6.43542e-01 -6.52566e-02 -2.27572e-01  7.02300e-02 -6.00996e-02  3.14152e-03  1.17261e-03  4.31073e-03 -2.56376e-03 -5.10839e-03  9.68490e-01  1.00000e+00
#
# Partial Rank Correlation Matrix between input and output:
#                 AFmax_4um   GAFmax_4um
# THICKNESS_SKIN -3.00919e-01 -3.05775e-01
# THICKNESS_SCT -7.73679e-01 -8.28065e-01
# THICKNESS_APONEUROSIS -5.51070e-01 -5.31739e-01
# THICKNESS_LOOSE_AREOLAR_TISSUE -7.61152e-01 -6.15604e-01
# THICKNESS_SKULL_OUTER -6.38045e-02 -4.58019e-02
# THICKNESS_SKULL_DIPLOE  5.11707e-02  3.00129e-02
# THICKNESS_SKULL_INNER -1.04497e-01 -4.11784e-03
# THICKNESS_CSF -6.77712e-02  4.42631e-02
# CONDUCTIVITY_SKIN -5.10158e-01 -6.13349e-01
# CONDUCTIVITY_SCT -8.89249e-01 -8.92280e-01
# CONDUCTIVITY_APONEUROSIS -1.19490e-01 -1.94475e-01
# CONDUCTIVITY_LOOSE_AREOLAR_TISSUE -4.51372e-01 -5.68401e-01
# CONDUCTIVITY_SKULL_CORTICAL  1.06080e-01  2.11062e-01
# CONDUCTIVITY_SKULL_DIPLOE -1.13258e-01 -1.76846e-01
# CONDUCTIVITY_CSF -2.85577e-02  3.41823e-03
#     RELDEPTH -1.41878e-02 -4.89318e-03
#     DIAMETER  1.42116e-02  1.16754e-02
#        ANGLE -1.96694e-02 -1.43431e-02
# ELECTRELDEPTH -1.36790e-02 -1.60565e-02
#
# -----------------------------------------------------------------------------
#
# <<<<< Iterator random_sampling completed.
# <<<<< Environment execution completed.
# DAKOTA execution time in seconds:
#   Total CPU        =    72.8852 [parent =    72.8852, child =     -1e-06]
#   Total wall clock =    72.8882

# %% [markdown]
# ## UQ - Input-Output distributions

# %%
from typing import List
import matplotlib.pyplot as plt

fig, axs = plt.subplots(4, 5, figsize=(20, 15), sharey=False)
axs: List[plt.Axes] = axs.flatten()

for var, ax in zip(
    variables_train[1:3] + ["POSITION"] + variables_train[3:-N_RESPONSES], axs
):
    ax.set_xlabel(var)
    if var == "POSITION":
        continue
    x = funs_data_processing.get_results(tmp_folder / f"predictions.dat", var)
    ax.hist(x, bins=50, density=True)
plt.suptitle("Input variable distributions")
plt.show()

# %%
RESPONSE = "AFmax_4um"

y_hat = funs_data_processing.get_results(tmp_folder / "predictions.dat", RESPONSE)

plt.hist(y_hat, bins=100, density=True)
plt.title(f"{RESPONSE} output distribution")
plt.xlabel(RESPONSE)
plt.xlim(0, 4000)
plt.ylim(0, 0.002)
plt.show()

# %%
RESPONSE = "GAFmax_4um"

y_hat = funs_data_processing.get_results(tmp_folder / "predictions.dat", RESPONSE)

plt.hist(y_hat, bins=100, density=True)
plt.title(f"{RESPONSE} output distribution")
plt.xlabel(RESPONSE)
plt.xlim(0, 75)
plt.ylim(0, 0.1)
plt.show()
