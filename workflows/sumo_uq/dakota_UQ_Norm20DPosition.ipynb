# %% [markdown]
# This notebook aims at evaluating 1 or 2 dimensional ranges on a SuMo built through Dakota.

# %%
import pathlib as pl
import shutil
import dakota.environment as dakenv
import sys, os
import numpy as np

# script_dir = pl.Path(__file__).parent
script_dir = pl.Path(os.getcwd())  ## how resilient is this?
print(script_dir)
sys.path.append(script_dir)

from utils import funs_create_dakota_conf, funs_data_processing
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq

# %% [markdown]
# ## Load & process input data

# %%
TRAINING_SAMPLES_FILE = "train_Norm20DPosition_1000LHS.dat"
tmp_folder = script_dir / ".tmp_output"
if tmp_folder.exists():
    shutil.rmtree(tmp_folder)
tmp_folder.mkdir()
TRAINING_SAMPLES_FILE = shutil.copy(TRAINING_SAMPLES_FILE, tmp_folder)
PROCESSED_TRAINING_FILE = funs_data_processing.process_input_file(
    TRAINING_SAMPLES_FILE,  #  N=100, filter_highest_N=10
)
variables_train = funs_data_processing.get_variable_names(PROCESSED_TRAINING_FILE)
print(variables_train)
# Out:
# ['%eval_id', 'RELDEPTH', 'DIAMETER', 'POSITION', 'ANGLE', 'ELECTRELDEPTH', 'THICKNESS_SKIN', 'THICKNESS_SCT', 'THICKNESS_APONEUROSIS', 'THICKNESS_LOOSE_AREOLAR_TISSUE', 'THICKNESS_SKULL_OUTER', 'THICKNESS_SKULL_DIPLOE', 'THICKNESS_SKULL_INNER', 'THICKNESS_CSF', 'CONDUCTIVITY_SKIN', 'CONDUCTIVITY_SCT', 'CONDUCTIVITY_APONEUROSIS', 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE', 'CONDUCTIVITY_SKULL_CORTICAL', 'CONDUCTIVITY_SKULL_DIPLOE', 'CONDUCTIVITY_CSF', 'AFmax_4um', 'GAFmax_4um']

# %% [markdown]
# ## Sample from input distributions

# %%
import pandas as pd
import copy
from create_20D_variables import (
    GEOMETRIC_VARIABLES,
    THICKNESS_VARIABLES,
    CONDUCTIVITY_VARIABLES,
)

# %%
N_RESPONSES = 2

dakota_conf_path = tmp_folder / "dakota.in"
dakota_conf = funs_create_dakota_conf.start_dakota_file()
dakota_conf += funs_create_dakota_conf.add_surrogate_model(
    PROCESSED_TRAINING_FILE, cross_validation_folds=None
)
dakota_conf += funs_create_dakota_conf.add_sampling_method(num_samples=10000)
# dakota_conf += funs_create_dakota_conf.add_variables(
#     variables=variables_train[1:-N_RESPONSES],
# )
dakota_conf += f"""
    variables
        id_variables = "VARIABLES"
        active uncertain
        uniform_uncertain = {len(GEOMETRIC_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in GEOMETRIC_VARIABLES.keys()])}
            upper_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["upper_bound"]) for var in GEOMETRIC_VARIABLES])}
            lower_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["lower_bound"]) for var in GEOMETRIC_VARIABLES])}
        normal_uncertain = {len(THICKNESS_VARIABLES)+len(CONDUCTIVITY_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in THICKNESS_VARIABLES.keys()])} {" ".join([f"'{var}'" for var in CONDUCTIVITY_VARIABLES.keys()])}
            means {" ".join([str(THICKNESS_VARIABLES[var]["mean"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["mean"]) for var in CONDUCTIVITY_VARIABLES])}
            std_deviations {" ".join([str(THICKNESS_VARIABLES[var]["std"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["std"]) for var in CONDUCTIVITY_VARIABLES])}
            lower_bounds {" ".join([str(THICKNESS_VARIABLES[var]["mean"]/5) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["mean"]/5) for var in CONDUCTIVITY_VARIABLES])}

"""
dakota_conf += funs_create_dakota_conf.add_responses(variables_train[-N_RESPONSES:])
print(dakota_conf)
funs_create_dakota_conf.write_to_file(dakota_conf, dakota_conf_path)
# Out:
#     environment
#         tabular_data
#             tabular_data_file = 'results.dat'
#
#
#         model
#             id_model 'SURR_MODEL'
#             surrogate global
#                 gaussian_process surfpack
#                 ## hopefully faster by removing CV
#                 import_build_points_file
#                     '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20DPosition_1000LHS_processed.txt'
#                     custom_annotated header use_variable_labels eval_id
#                 export_approx_points_file "predictions.dat"
#                 export_approx_variance_file "variances.dat"
#
#         method
#             id_method = 'SAMPLING'
#             sample_type
#                 lhs
#             sampling
#                 samples = 10000
#                 seed = 1234
#
#
#     variables
#         id_variables = "VARIABLES"
#         active uncertain
#         uniform_uncertain = 5
#             descriptors 'RELDEPTH' 'DIAMETER' 'POSITION' 'ANGLE' 'ELECTRELDEPTH'
#             upper_bounds 1.0 1.0 21.0 90.0 1.0
#             lower_bounds 0.0 0.1 -21.0 0.0 0.0
#         normal_uncertain = 15
#             descriptors 'THICKNESS_SKIN' 'THICKNESS_SCT' 'THICKNESS_APONEUROSIS' 'THICKNESS_LOOSE_AREOLAR_TISSUE' 'THICKNESS_SKULL_OUTER' 'THICKNESS_SKULL_DIPLOE' 'THICKNESS_SKULL_INNER' 'THICKNESS_CSF' 'CONDUCTIVITY_SKIN' 'CONDUCTIVITY_SCT' 'CONDUCTIVITY_APONEUROSIS' 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE' 'CONDUCTIVITY_SKULL_CORTICAL' 'CONDUCTIVITY_SKULL_DIPLOE' 'CONDUCTIVITY_CSF'
#             means 0.514 0.944 0.247 0.655 1.83 2.84 1.44 3.6 0.148297101 0.077621273 0.079195857 0.079195857 0.00644673 0.09975 1.87899971
#             std_deviations 0.108 0.331 0.101 0.376 0.5 0.5 0.5 0.5 0.042145684 0.093082005 0.023344569 0.023344569 0.002535023 0.121595589 0.685074315
#             lower_bounds 0.1028 0.1888 0.0494 0.131 0.366 0.568 0.288 0.72 0.029659420199999998 0.0155242546 0.015839171399999998 0.015839171399999998 0.001289346 0.019950000000000002 0.375799942
#
#
#
#         responses
#             id_responses = 'RESPONSES'
#             descriptors 'AFmax_4um' 'GAFmax_4um'
#             objective_functions = 2
#             no_gradients
#             no_hessians

# %% [markdown]
# ## Create & run Dakota study

# %%
os.chdir(tmp_folder)
shutil.copy(script_dir / "execute_dakota.py", tmp_folder)
# !python execute_dakota.py
os.chdir(script_dir)
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output
# Dakota version 6.19+ (stable) released Aug  8 2024.
# Repository revision 494027b (2024-04-29) built Aug  8 2024 14:37:02.
# Running serial Dakota executable in serial mode.
# Start time: Thu Sep 19 17:35:48 2024
#
# Using provided Dakota input string
# Writing new restart file 'dakota.rst'.
# Surrogate model retrieving points with 20 variables and 2 response
# functions from file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20DPosition_1000LHS_processed.txt'
#
# Info (Surrogate model with id 'SURR_MODEL' import_build_points):
# Reordering variables imported from tabular file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_Norm20DPosition_1000LHS_processed.txt'
# based on labels in header.
#
# Surrogate model retrieved 1000 total points.
#
# >>>>> Executing environment.
#
# >>>>> Running random_sampling iterator.
#
# NonD lhs Samples = 10000 Seed (user-specified) = 1234
#
# >>>>> Building global_kriging approximations.
# Constructing global approximations with no anchor, 0 DACE samples, and 1000 reused points.
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=20; #pts=1000; used 1000/1000 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[2.33688, 1.83904, 0.501194, 1.65396, 9.53257, 3.77648, 9.02312, 4.3852, 0.803054, 0.356279, 0.140124, 0.445166, 0.0414588, 1.47217, 12.4946, 1.00119, 0.901068, 13.2449, 286.071, 1.00119]^T
# found by the "global" optimization_method;
# unadjusted variance=306567; "per equation" log(likelihood)=3.21731;
# rcond(R)=1.86425e-06; rcond(G_Rinv_Gtran)=0.0034285; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 41 terms) was requested for the trend function; the build
# data was sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.557222 -0.0334585*x0 -0.120233*x1 ...
#                -0.0531929*x2 -0.102194*x3 + 0.00354042*x4 ...
#                -0.044654*x5 + 0.0104492*x6 + 0.0256666*x7 ...
#                -0.0308348*x8 -0.0493276*x9 + 0.00675086*x10 ...
#                -0.0291996*x11 + 0.0170424*x12 -0.00795589*x13 ...
#                -0.00128924*x14 + 0.025116*x15 -0.123207*x16 ...
#                -0.0763461*x17 -0.024726*x18 -0.0565449*x19 ...
#                -0.00127575*x0^2 + 0.130861*x1^2 + 0.0257132*x2^2 + ...
#                0.12919*x3^2 + 0.00977387*x4^2 + 0.00263495*x5^2 + ...
#                0.0108167*x6^2 + 0.0816711*x7^2 + 0.00438254*x8^2 + ...
#                0.105229*x9^2 + 0.0147354*x10^2 + 0.00610241*x11^2 + ...
#                0.0264104*x12^2 + 0.00659614*x13^2 -0.00621209*x14^2 + ...
#                0.0514317*x15^2 + 0.0713054*x16^2 -0.116895*x17^2 + ...
#                0.0317161*x18^2 + 0.0426931*x19^2
# ------------------------------------
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=20; #pts=1000; used 1000/1000 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[0.736072, 1.83904, 0.501194, 1.65396, 3.00257, 3.77648, 2.84211, 4.3852, 0.252946, 0.356279, 0.140124, 0.140218, 0.0130587, 0.463706, 3.93555, 1.00119, 0.901068, 13.2449, 28.3819, 3.17857]^T
# found by the "global" optimization_method;
# unadjusted variance=161.288; "per equation" log(likelihood)=2.65364;
# rcond(R)=0.000103259; rcond(G_Rinv_Gtran)=0.00196549; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 41 terms) was requested for the trend function; the build
# data was sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.485254 -0.0766363*x0 -0.14641*x1 ...
#                -0.0172067*x2 -0.0750872*x3 + 0.0225764*x4 ...
#                -0.0111844*x5 -0.00231588*x6 + 0.0371578*x7 ...
#                -0.0652226*x8 -0.117493*x9 -0.0116042*x10 ...
#                -0.0961304*x11 -0.0404743*x12 -0.0379504*x13 ...
#                -0.00287974*x14 + 0.00128272*x15 -0.0621956*x16 + ...
#                0.0351083*x17 -0.268035*x18 -0.0275047*x19 + ...
#                0.0635117*x0^2 + 0.11154*x1^2 + 0.0330394*x2^2 + ...
#                0.0842649*x3^2 + 0.00915625*x4^2 -0.0258756*x5^2 ...
#                -0.0144833*x6^2 + 0.0412545*x7^2 + 0.0752756*x8^2 + ...
#                0.0771404*x9^2 -0.00717855*x10^2 + 0.0430345*x11^2 + ...
#                0.0943908*x12^2 -0.00304865*x13^2 -0.0170094*x14^2 ...
#                -0.0138603*x15^2 + 0.058271*x16^2 + 0.324097*x17^2 + ...
#                0.33543*x18^2 + 0.0621155*x19^2
# ------------------------------------
#
# <<<<< global_kriging approximation builds completed.
# Beginning Approximate Fn Evaluations...
# <<<<< Function evaluation summary (APPROX_INTERFACE_1): 10000 total (10000 new, 0 duplicate)
# <<<<< Best parameters          =
#                       4.3713361892e-01 THICKNESS_SKIN
#                       3.7291274428e-01 THICKNESS_SCT
#                       2.0796754003e-01 THICKNESS_APONEUROSIS
#                       3.7670618346e-01 THICKNESS_LOOSE_AREOLAR_TISSUE
#                       1.5900972607e+00 THICKNESS_SKULL_OUTER
#                       2.9928958859e+00 THICKNESS_SKULL_DIPLOE
#                       7.2504958758e-01 THICKNESS_SKULL_INNER
#                       4.0889343285e+00 THICKNESS_CSF
#                       1.5839601421e-01 CONDUCTIVITY_SKIN
#                       1.9964248120e-01 CONDUCTIVITY_SCT
#                       1.5685009371e-01 CONDUCTIVITY_APONEUROSIS
#                       1.1891106994e-01 CONDUCTIVITY_LOOSE_AREOLAR_TISSUE
#                       8.0351501410e-03 CONDUCTIVITY_SKULL_CORTICAL
#                       1.4868624085e-01 CONDUCTIVITY_SKULL_DIPLOE
#                       1.8164240138e+00 CONDUCTIVITY_CSF
#                       7.3155929463e-01 RELDEPTH
#                       9.5623002734e-01 DIAMETER
#                      -1.9461341672e+00 POSITION
#                       5.8955952031e+01 ANGLE
#                       6.2014905766e-01 ELECTRELDEPTH
# <<<<< Best objective functions =
#                      -3.5016899651e+02
#                       2.9939996977e+00
# <<<<< Best evaluation ID: 5435
# -----------------------------------------------------------------------------
# Statistics based on 10000 samples:
#
# Sample moment statistics for each response function:
#                             Mean           Std Dev          Skewness          Kurtosis
#      AFmax_4um  2.8483918770e+02  3.0183225554e+02  2.0264879272e+00  5.8723649282e+00
#     GAFmax_4um  1.8713904773e+01  1.1336475676e+01  7.7496208288e-01  5.5748865722e-01
#
# 95% confidence intervals for each response function:
#                     LowerCI_Mean      UpperCI_Mean    LowerCI_StdDev    UpperCI_StdDev
#      AFmax_4um  2.7892266801e+02  2.9075570738e+02  2.9770658212e+02  3.0607470371e+02
#     GAFmax_4um  1.8491687033e+01  1.8936122512e+01  1.1181520082e+01  1.1495817196e+01
#
# Simple Correlation Matrix among all inputs and outputs:
#              THICKNESS_SKIN THICKNESS_SCT THICKNESS_APONEUROSIS THICKNESS_LOOSE_AREOLAR_TISSUE THICKNESS_SKULL_OUTER THICKNESS_SKULL_DIPLOE THICKNESS_SKULL_INNER THICKNESS_CSF CONDUCTIVITY_SKIN CONDUCTIVITY_SCT CONDUCTIVITY_APONEUROSIS CONDUCTIVITY_LOOSE_AREOLAR_TISSUE CONDUCTIVITY_SKULL_CORTICAL CONDUCTIVITY_SKULL_DIPLOE CONDUCTIVITY_CSF     RELDEPTH     DIAMETER     POSITION        ANGLE ELECTRELDEPTH    AFmax_4um   GAFmax_4um
# THICKNESS_SKIN  1.00000e+00
# THICKNESS_SCT -1.10652e-03  1.00000e+00
# THICKNESS_APONEUROSIS -3.37196e-04  9.98678e-04  1.00000e+00
# THICKNESS_LOOSE_AREOLAR_TISSUE  1.79030e-03 -1.05930e-03  3.20248e-03  1.00000e+00
# THICKNESS_SKULL_OUTER  7.07606e-05 -5.48779e-04  3.20151e-04 -4.71184e-03  1.00000e+00
# THICKNESS_SKULL_DIPLOE -1.45023e-05  2.19953e-04  3.57381e-05  2.24986e-03 -2.21416e-04  1.00000e+00
# THICKNESS_SKULL_INNER -1.37383e-04  3.17568e-04 -1.37751e-04 -1.47215e-03 -1.78463e-04  1.13222e-04  1.00000e+00
# THICKNESS_CSF  1.30979e-04  8.53794e-04  9.26807e-04  3.86572e-04 -6.07144e-05 -3.83234e-05  2.23282e-04  1.00000e+00
#   GAFmax_4um -5.25920e-02 -1.60450e-01 -8.15956e-02 -1.95840e-01  3.71310e-02 -1.58016e-02  1.91632e-02  8.97008e-03 -7.11917e-02 -2.42206e-01 -4.61733e-02 -8.94852e-02 -4.43837e-02 -2.78805e-02  4.47180e-02  1.19914e-02 -1.50822e-01 -9.96414e-02 -6.00833e-01 -6.96400e-02  5.96402e-01  1.00000e+00
#
# Partial Rank Correlation Matrix between input and output:
#                 AFmax_4um   GAFmax_4um
# THICKNESS_SKIN -7.00798e-02 -8.18494e-02
# THICKNESS_SCT -2.68675e-01 -2.37734e-01
# THICKNESS_APONEUROSIS -1.27959e-01 -1.19075e-01
# THICKNESS_LOOSE_AREOLAR_TISSUE -1.48528e-01 -2.79284e-01
# THICKNESS_SKULL_OUTER  3.95426e-02  5.56487e-02
# THICKNESS_SKULL_DIPLOE -1.72032e-02 -2.56663e-02
# THICKNESS_SKULL_INNER  5.57285e-02  2.92947e-02
# THICKNESS_CSF  7.45924e-03  2.05027e-02
# CONDUCTIVITY_SKIN -8.52926e-02 -1.07596e-01
# CONDUCTIVITY_SCT -3.20277e-01 -3.35798e-01
# CONDUCTIVITY_APONEUROSIS -6.34830e-02 -6.69461e-02
# CONDUCTIVITY_LOOSE_AREOLAR_TISSUE -1.00081e-01 -1.34057e-01
# CONDUCTIVITY_SKULL_CORTICAL -4.23332e-02 -6.89698e-02
# CONDUCTIVITY_SKULL_DIPLOE  1.53603e-02 -4.41871e-02
# CONDUCTIVITY_CSF  5.75417e-02  7.11606e-02
#     RELDEPTH  1.84563e-01  2.04509e-02
#     DIAMETER -4.93825e-01 -2.19660e-01
#     POSITION -6.35917e-01 -1.48545e-01
#        ANGLE -2.67361e-01 -6.68599e-01
# ELECTRELDEPTH -2.13547e-01 -1.04735e-01
#
# -----------------------------------------------------------------------------
#
# <<<<< Iterator random_sampling completed.
# <<<<< Environment execution completed.
# DAKOTA execution time in seconds:
#   Total CPU        =    60.2898 [parent =    60.2898, child =     -1e-06]
#   Total wall clock =    60.2949

# %% [markdown]
# ## UQ - Input-Output distributions

# %%
from typing import List
import matplotlib.pyplot as plt

fig, axs = plt.subplots(4, 5, figsize=(20, 15), sharey=False)
axs: List[plt.Axes] = axs.flatten()

for var, ax in zip(variables_train[1:-N_RESPONSES], axs):
    x = funs_data_processing.get_results(tmp_folder / f"predictions.dat", var)
    ax.hist(x, bins=50, density=True)
    ax.set_xlabel(var)
plt.suptitle("Input variable distributions")
plt.show()

# %%
RESPONSE = "AFmax_4um"

y_hat = funs_data_processing.get_results(tmp_folder / "predictions.dat", RESPONSE)

plt.hist(y_hat, bins=100, density=True)
plt.title(f"{RESPONSE} output distribution")
plt.xlabel(RESPONSE)
plt.xlim(0, 4000)
plt.ylim(0, 0.002)
plt.show()

# %%
RESPONSE = "GAFmax_4um"

y_hat = funs_data_processing.get_results(tmp_folder / "predictions.dat", RESPONSE)

plt.hist(y_hat, bins=100, density=True)
plt.title(f"{RESPONSE} output distribution")
plt.xlabel(RESPONSE)
plt.xlim(0, 75)
plt.ylim(0, 0.1)
plt.show()
