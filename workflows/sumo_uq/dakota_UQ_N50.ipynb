# %% [markdown]
# This notebook aims at evaluating 1 or 2 dimensional ranges on a SuMo built through Dakota.

# %%
import pathlib as pl
import shutil
import dakota.environment as dakenv
import sys, os
import numpy as np

# script_dir = pl.Path(__file__).parent
script_dir = pl.Path(os.getcwd())  ## how resilient is this?
print(script_dir)
sys.path.append(script_dir)

from utils import funs_create_dakota_conf, funs_data_processing
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq

# %% [markdown]
# ## Load & process input data

# %%
TRAINING_SAMPLES_FILE = "train_20D_1000LHS.dat"
tmp_folder = script_dir / ".tmp_output"
if tmp_folder.exists():
    shutil.rmtree(tmp_folder)
tmp_folder.mkdir()
TRAINING_SAMPLES_FILE = shutil.copy(TRAINING_SAMPLES_FILE, tmp_folder)
PROCESSED_TRAINING_FILE = funs_data_processing.process_input_file(
    TRAINING_SAMPLES_FILE, N=50
)
variables_train = funs_data_processing.get_variable_names(PROCESSED_TRAINING_FILE)
print(variables_train)
# Out:
# ['%eval_id', 'RELDEPTH', 'DIAMETER', 'ANGLE', 'ELECTRELDEPTH', 'THICKNESS_SKIN', 'THICKNESS_SCT', 'THICKNESS_APONEUROSIS', 'THICKNESS_LOOSE_AREOLAR_TISSUE', 'THICKNESS_SKULL_OUTER', 'THICKNESS_SKULL_DIPLOE', 'THICKNESS_SKULL_INNER', 'THICKNESS_CSF', 'CONDUCTIVITY_SKIN', 'CONDUCTIVITY_SCT', 'CONDUCTIVITY_APONEUROSIS', 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE', 'CONDUCTIVITY_SKULL_CORTICAL', 'CONDUCTIVITY_SKULL_DIPLOE', 'CONDUCTIVITY_CSF', 'AFmax_4um', 'GAFmax_4um']

# %% [markdown]
# ## Sample from input distributions

# %%
import pandas as pd
import copy
from create_20D_variables import (
    GEOMETRIC_VARIABLES,
    THICKNESS_VARIABLES,
    CONDUCTIVITY_VARIABLES,
)

# %%
N_RESPONSES = 2

dakota_conf_path = tmp_folder / "dakota.in"
dakota_conf = funs_create_dakota_conf.start_dakota_file()
dakota_conf += funs_create_dakota_conf.add_surrogate_model(
    PROCESSED_TRAINING_FILE, cross_validation_folds=None
)
dakota_conf += funs_create_dakota_conf.add_sampling_method(num_samples=10000)
# dakota_conf += funs_create_dakota_conf.add_variables(
#     variables=variables_train[1:-N_RESPONSES],
# )
dakota_conf += f"""
    variables
        id_variables = "VARIABLES"
        active uncertain
        uniform_uncertain = {len(GEOMETRIC_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in GEOMETRIC_VARIABLES.keys()])}
            upper_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["upper_bound"]) for var in GEOMETRIC_VARIABLES])}
            lower_bounds {" ".join([str(GEOMETRIC_VARIABLES[var]["lower_bound"]) for var in GEOMETRIC_VARIABLES])}
        normal_uncertain = {len(THICKNESS_VARIABLES)+len(CONDUCTIVITY_VARIABLES)}
            descriptors {" ".join([f"'{var}'" for var in THICKNESS_VARIABLES.keys()])} {" ".join([f"'{var}'" for var in CONDUCTIVITY_VARIABLES.keys()])}
            means {" ".join([str(THICKNESS_VARIABLES[var]["mean"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["mean"]) for var in CONDUCTIVITY_VARIABLES])}
            std_deviations {" ".join([str(THICKNESS_VARIABLES[var]["std"]) for var in THICKNESS_VARIABLES])} {" ".join([str(CONDUCTIVITY_VARIABLES[var]["std"]) for var in CONDUCTIVITY_VARIABLES])}
"""
dakota_conf += funs_create_dakota_conf.add_responses(variables_train[-N_RESPONSES:])
print(dakota_conf)
funs_create_dakota_conf.write_to_file(dakota_conf, dakota_conf_path)
# Out:
#     environment
#         tabular_data
#             tabular_data_file = 'results.dat'
#
#
#         model
#             id_model 'SURR_MODEL'
#             surrogate global
#                 gaussian_process surfpack
#                 ## hopefully faster by removing CV
#                 import_build_points_file
#                     '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_20D_1000LHS_processed.txt'
#                     custom_annotated header eval_id
#                 export_approx_points_file "predictions.dat"
#                 export_approx_variance_file "variances.dat"
#
#         method
#             id_method = 'SAMPLING'
#             sample_type
#                 lhs
#             sampling
#                 samples = 10000
#                 seed = 1234
#
#
#     variables
#         id_variables = "VARIABLES"
#         active uncertain
#         uniform_uncertain = 4
#             descriptors 'RELDEPTH' 'DIAMETER' 'ANGLE' 'ELECTRELDEPTH'
#             upper_bounds 1.0 1.0 90.0 1.0
#             lower_bounds 0.0 0.1 0.0 0.0
#         normal_uncertain = 15
#             descriptors 'THICKNESS_SKIN' 'THICKNESS_SCT' 'THICKNESS_APONEUROSIS' 'THICKNESS_LOOSE_AREOLAR_TISSUE' 'THICKNESS_SKULL_OUTER' 'THICKNESS_SKULL_DIPLOE' 'THICKNESS_SKULL_INNER' 'THICKNESS_CSF' 'CONDUCTIVITY_SKIN' 'CONDUCTIVITY_SCT' 'CONDUCTIVITY_APONEUROSIS' 'CONDUCTIVITY_LOOSE_AREOLAR_TISSUE' 'CONDUCTIVITY_SKULL_CORTICAL' 'CONDUCTIVITY_SKULL_DIPLOE' 'CONDUCTIVITY_CSF'
#             means 0.514 0.944 0.247 0.655 1.83 2.84 1.44 3.6 0.148297101 0.077621273 0.079195857 0.079195857 0.00644673 0.09975 1.87899971
#             std_deviations 0.108 0.331 0.101 0.376 0.5 0.5 0.5 0.5 0.042145684 0.093082005 0.023344569 0.023344569 0.002535023 0.121595589 0.685074315
#
#
#         responses
#             id_responses = 'RESPONSES'
#             descriptors 'AFmax_4um' 'GAFmax_4um'
#             objective_functions = 2
#             no_gradients
#             no_hessians

# %% [markdown]
# ## Create & run Dakota study

# %%
os.chdir(tmp_folder)
shutil.copy(script_dir / "execute_dakota.py", tmp_folder)
# !python execute_dakota.py
os.chdir(script_dir)
# Out:
# /home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output
# Dakota version 6.19+ (stable) released Aug  8 2024.
# Repository revision 494027b (2024-04-29) built Aug  8 2024 14:37:02.
# Running serial Dakota executable in serial mode.
# Start time: Tue Sep 10 14:17:20 2024
#
# Using provided Dakota input string
# Writing new restart file 'dakota.rst'.
# Surrogate model retrieving points with 19 variables and 2 response
# functions from file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_20D_1000LHS_processed.txt'
#
# Warning (Surrogate model with id 'SURR_MODEL' import_build_points):
# Variable labels in header of tabular file '/home/ordonez/osparc-services/osparc-dakota-examples/workflows/sumo_uq/.tmp_output/train_20D_1000LHS_processed.txt' are a
# permutation of expected variable labels; consider use_variable_labels keyword.
# Surrogate model retrieved 50 total points.
#
# >>>>> Executing environment.
#
# >>>>> Running random_sampling iterator.
#
# NonD lhs Samples = 10000 Seed (user-specified) = 1234
#
# >>>>> Building global_kriging approximations.
# Constructing global approximations with no anchor, 0 DACE samples, and 50 reused points.
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=19; #pts=50; used 50/50 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[1.09741, 7.25757, 32.3409, 2.59678, 11.4588, 1.53713, 3.45316, 17.7254, 3.79421, 16.2419, 10.6383, 18.5622, 0.979038, 0.264514, 1.49028, 3.65437, 3.64969, 328.893, 4.48156]^T
# found by the "global" optimization_method;
# unadjusted variance=33586.7; "per equation" log(likelihood)=2.2086;
# rcond(R)=0.000257387; rcond(G_Rinv_Gtran)=0.288086; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 39 terms) was requested for the trend function; the build
# data was NOT sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.314107 -0.038065*x0 -0.1715*x2 ...
#                -0.827453*x3 + 0.0329665*x8 -0.0973113*x12 + ...
#                0.0218338*x18 + 1.48383*x1^2 + 0.195627*x4^2 + ...
#                0.410691*x9^2 -0.306557*x11^2
# ------------------------------------
# --- Surfpack Kriging Diagnostics ---
# KM: #real inputs=19; #pts=50; used 50/50 pts;
# using the Gaussian correlation function with (unscaled)
# Correlation lengths=[1.09741, 2.28599, 32.3409, 8.24425, 11.4588, 4.88007, 10.9631, 5.58316, 3.79421, 16.2419, 3.35085, 18.5622, 0.308378, 2.66613, 1.49028, 0.362559, 0.362095, 328.893, 4.48156]^T
# found by the "global" optimization_method;
# unadjusted variance=24.6509; "per equation" log(likelihood)=1.92012;
# rcond(R)=0.000168743; rcond(G_Rinv_Gtran)=0.263726; [if either rcond is less
# than 2^-40 (approx 9.095*10^-13) then the matrix is ill-conditioned and
# that "voids the warranty" of the Kriging Model]; nugget=0.  A reduced_polynomial
# of order 2 (with 39 terms) was requested for the trend function; the build
# data was NOT sufficient to use the requested trend function; the highest total
# polynomial order of any term in the utlized trend function is 2;
# for SCALED inputs and outputs the utilized trend function is
# betaHat^T*g(x)=-0.111091 -0.0651768*x0 -0.150962*x2 + ...
#                0.229168*x8 + 0.0498736*x9 -0.0229077*x10 + ...
#                0.0189451*x12 + 0.0347881*x18 + 1.06434*x3^2 ...
#                -0.204026*x11^2 -0.6397*x13^2
# ------------------------------------
#
# <<<<< global_kriging approximation builds completed.
# Beginning Approximate Fn Evaluations...
# <<<<< Function evaluation summary (APPROX_INTERFACE_1): 10000 total (10000 new, 0 duplicate)
# <<<<< Best parameters          =
#                       7.2501648020e-01 THICKNESS_SKIN
#                       1.1052357439e+00 THICKNESS_SCT
#                       2.1590892566e-01 THICKNESS_APONEUROSIS
#                       1.8126606768e+00 THICKNESS_LOOSE_AREOLAR_TISSUE
#                       1.8426269724e+00 THICKNESS_SKULL_OUTER
#                       2.1363952708e+00 THICKNESS_SKULL_DIPLOE
#                       1.5973877689e+00 THICKNESS_SKULL_INNER
#                       4.0438178263e+00 THICKNESS_CSF
#                       1.1637135835e-01 CONDUCTIVITY_SKIN
#                       8.5498361769e-02 CONDUCTIVITY_SCT
#                       9.3455284587e-02 CONDUCTIVITY_APONEUROSIS
#                       7.2360116156e-02 CONDUCTIVITY_LOOSE_AREOLAR_TISSUE
#                       7.7411853547e-03 CONDUCTIVITY_SKULL_CORTICAL
#                       1.7667156513e-01 CONDUCTIVITY_SKULL_DIPLOE
#                       6.6139238413e-01 CONDUCTIVITY_CSF
#                       3.5155971779e-02 RELDEPTH
#                       3.5301896700e-01 DIAMETER
#                       1.1681479840e+01 ANGLE
#                       1.6945329085e-01 ELECTRELDEPTH
# <<<<< Best objective functions =
#                      -7.1522994230e+01
#                       8.5638487395e+00
# <<<<< Best evaluation ID: 9385
# -----------------------------------------------------------------------------
# Statistics based on 10000 samples:
#
# Sample moment statistics for each response function:
#                             Mean           Std Dev          Skewness          Kurtosis
#      AFmax_4um  3.0201494669e+02  9.5440400063e+01  1.4049130183e-01  3.0333624377e-01
# ELECTRELDEPTH  4.29786e-03 -7.67144e-04 -2.15548e-03  1.59922e-04  4.88385e-03 -2.03823e-05 -2.83708e-03 -2.72909e-04 -2.42698e-03 -1.45394e-03 -1.85823e-03 -1.35751e-03 -1.16408e-03  5.92999e-04  3.08769e-03 -3.16658e-03 -1.34309e-03  3.44563e-04  1.00000e+00
#    AFmax_4um -2.93215e-02 -3.46474e-03 -1.44791e-02 -8.67284e-01  1.43673e-02  1.25619e-02 -3.68858e-03  5.36212e-03 -3.34937e-03 -4.33768e-02 -5.73292e-03  1.17449e-02 -4.85042e-03 -1.55242e-01  2.29430e-01  4.12446e-03  3.21058e-03  7.62841e-03  4.88309e-03  1.00000e+00
#   GAFmax_4um -1.79101e-01 -2.34262e-02  1.24796e-02 -2.20419e-03  7.82453e-03 -1.47541e-02  6.42347e-04 -2.07516e-02  5.37687e-02  2.08071e-02  2.25996e-03  2.04113e-02  4.89633e-03  5.39379e-03 -8.94623e-02 -1.30563e-01 -4.73172e-01 -3.60078e-03  1.01319e-01 -2.11456e-02  1.00000e+00
#
# Partial Rank Correlation Matrix between input and output:
#                 AFmax_4um   GAFmax_4um
# THICKNESS_SKIN -8.00899e-02 -2.09177e-01
# THICKNESS_SCT -3.63894e-03 -2.90395e-02
# THICKNESS_APONEUROSIS -3.63341e-02  1.43709e-02
# THICKNESS_LOOSE_AREOLAR_TISSUE -9.05688e-01 -2.60119e-03
# THICKNESS_SKULL_OUTER  3.54979e-02  4.89677e-03
# THICKNESS_SKULL_DIPLOE  4.68342e-02 -2.17324e-02
# THICKNESS_SKULL_INNER -1.06308e-02 -8.62384e-04
# THICKNESS_CSF  1.11371e-02 -2.66861e-02
# CONDUCTIVITY_SKIN -9.70131e-03  6.04846e-02
# CONDUCTIVITY_SCT -1.01890e-01  2.02397e-02
# CONDUCTIVITY_APONEUROSIS -6.54156e-03  2.89650e-03
# CONDUCTIVITY_LOOSE_AREOLAR_TISSUE  2.10942e-02  2.51097e-02
# CONDUCTIVITY_SKULL_CORTICAL -1.21948e-02  6.82283e-03
# CONDUCTIVITY_SKULL_DIPLOE -3.62641e-01  7.91599e-03
# CONDUCTIVITY_CSF  4.95866e-01 -1.04059e-01
#     RELDEPTH  1.20265e-02 -1.52439e-01
#     DIAMETER  6.49659e-03 -4.91470e-01
#        ANGLE  2.02860e-02 -4.27038e-03
# ELECTRELDEPTH  1.07548e-02  1.20090e-01
#
# -----------------------------------------------------------------------------
#
# <<<<< Iterator random_sampling completed.
# <<<<< Environment execution completed.
# DAKOTA execution time in seconds:
#   Total CPU        =    1.14473 [parent =    1.14473, child =          0]
#   Total wall clock =    1.16112

# %% [markdown]
# ## UQ - Input-Output distributions

# %%
from typing import List
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 6, figsize=(20, 10), sharey=False)
axs: List[plt.Axes] = axs.flatten()

for var, ax in zip(variables_train[1:-N_RESPONSES], axs):
    x = funs_data_processing.get_results(tmp_folder / f"predictions.dat", var)
    ax.hist(x, bins=50, density=True)
    ax.set_xlabel(var)
plt.suptitle("Input variable distributions")
plt.show()

# %%
RESPONSE = "GAFmax_4um"

y_hat = funs_data_processing.get_results(tmp_folder / "predictions.dat", RESPONSE)

plt.hist(y_hat, bins=50, density=True)
plt.title("GAF output distribution")
plt.xlabel(RESPONSE)
plt.show()
